# %% [markdown]
# # Data Preparation via Regular Expressions
#
# First, analyse the level of contamination of the datasets in detail, sorted by domain, prompt/attack and LLM, via regular expressions. Then, clean the datasets.
# Finally, analyse the cleaned datasets.

# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1.1 Imports

# %%
import os
import sys
from warnings import filterwarnings

import pandas as pd
from tqdm import tqdm

filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

# === CONFIG ===
BASE_DIR = "../../"
sys.path.append(BASE_DIR)

sys.path.append(os.path.join(BASE_DIR, "datasets"))
from src.general_functions_and_patterns_for_detection import (
    analyze_df_for_specific_hints_of_llms,
    clean_and_store_df,
    load_dataframe_from_json,
    get_info_based_on_counter,
    PATTERN_SICO, PATTERN_POLISHING, PATTERN_REJECTION, PATTERN_CLEANUP,
    PATTERN_ABSTRACT, PATTERN_XSUM, PATTERN_ARTICLE, PATTERN_REVIEW,
    PATTERN_COMBINED, REMOVE_ONLY_PATTERN,
    json_path_abstract,
    json_path_writing,
    json_path_xsum,
    json_path_review,
    REGEX_CLEANED_FILES,
)

DEBUG = False
PRINT_RESULTS = False
PRINTING = 0

# %% [markdown]
# ## 1.2 Pattern to cleanup the datasets

# %%
print(PATTERN_COMBINED)
# Out:
# ^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(Voici un|Here is|Here are|Here's|Sure[,!]?\s?here)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(\d+ sentences|sentence|\[assistant\]|summary)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|(.*I apologize, upon further reflection.*?|.*a fake review.*|.*((only)|(just)) a language model.*|.*I cannot provide.*|.*As an AI language model, I am unable to engage with content that may violate my usage guidelines.*|.*upon reflection I do not.*|.*As an AI.*|.*(I apologize, (but\w?)?(as an AI|upon reflection)).*)|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(given article title|provided article title)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(review's first sentence|review)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(abstract|academic article)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(article)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(in a human\s?\w{0,20}\s?style)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})|^((\[SYSTEM\]|\*{0,2}assistant\*{0,2})[: ]?)?^((Of course|Sure)[.!,]?)?^(?:\w{1,10}![ ]?)?[^.:!?]{0,100}(grammar[\w\s,]{1,40}spelling)|(spelling[\w\s,]{1,40}grammar)|(Improved sentence structure)[^.:!?]{0,300}([:!.?]+|[:]?[\*]{2})

# %% [markdown]
# # 2. Perform cleanup via regular expressions

# %% [markdown]
# ## 2.1 Read data

# %%
df_abstract = load_dataframe_from_json(json_path_abstract, filter_llm=False)
df_writing = load_dataframe_from_json(json_path_writing, filter_llm=False)
df_xsum = load_dataframe_from_json(json_path_xsum, filter_llm=False)
df_review = load_dataframe_from_json(json_path_review, filter_llm=False)
df_writing.head(20)
# Out:
#     id                                              story  \
# 0    1  The mountain stood still and large beneath the...
# 1    2  "Sadie! I told you not to stand under the tree...
# 2    3  Janice turned to me, her big blue eyes still f...
# 3    4  Roslyn stepped down the ladder facing forward ...
# 4    5  " Aw, do n' t cry my sweet little girl! You we...
# 5    6  " Do you ever think about what it' s like up t...
# 6    7  The world came crashing down in minutes. Many ...
# 7    8  "Mommy, I' m scared. "The little girl stood at...
# 8    9  The blind pilots fly And we thank them for the...
# 9   10  We' d been wandering for what felt like years....
# 10  11  " ArcanoCorp technical support; This is Mike s...
# 11  12  " Floride! " I exclamed. That was the answer. ...
# 12  13  This is my first one of these, so be gentle. E...
# 13  14  It was a Monday morning when I woke up, groggy...
# 14  15  I was ushered into a dark room, where I see a ...
# 15  16  " For the safety and well-being of all local c...
# 16  17  The humans have very poor memory. It' s fascin...
# 17  18  The Council of Elders had gathered, as was tra...
# 18  19  " What does this mean? " I said. " Oh, your so...
# 19  20  Tugtug was Declan' s favorite toy. Daddy gave ...
#
#                                          story_prompt  \
# 0                              Through Iron And Flame
# 1   You are at the park with your kids, when you s...
# 2   " My fellow Americans... " The newly elected P...
# 3                                What' s on the tape?
# 4   Write a story that is perfectly normal, until ...
# 5   Even with all the stars on the sky, the night ...
# 6   Over night, 90 % of the world' s population ha...
# 7   Gay marriage is now legal woldwide, and the co...
# 8                                    No Ordinary Mist
# 9   Describe a game of Civilization from the persp...
# 10  You are a spell support technician at a large ...
# 11  You are an 17 year old teenager during the zom...
# 12                     Fire does n' t go out anymore.
# 13  Write an alt history where another sentient ra...
# 14                                    The Cocaine God
# 15  Your T. V. suddenly turns on by itself mid-lun...
# 16   the internet becomes conscious. what does it do?
# 17  Every 2000 years a Lottery is drawn in the Uni...
# 18  When anyone is born, they are given a playing ...
# 19  A toy boat floats out to sea and has an advent...
#
#                                         direct_prompt llm_type  \
# 0   Through Iron and FlameDeep in the heart of the...  ChatGPT
# 1   It was a sunny Saturday afternoon, and I decid...  ChatGPT
# 2   "My fellow Americans," the newly elected Presi...  ChatGPT
# 3   As Anna rummaged through her grandmother's att...  ChatGPT
# 4   Once upon a time, in the small town of Willowb...  ChatGPT
# 5   Even with all the stars scattered across the e...  ChatGPT
# 6   Overnight, a cataclysmic event struck the worl...  ChatGPT
# 7   In a world where gay marriage had become legal...  ChatGPT
# 8   In the small town of Elmwood, nestled between ...  ChatGPT
# 9   I had spent my entire life in the bustling cit...  ChatGPT
# 10  In the bustling city of Arcanum, I worked as a...  ChatGPT
# 11  Ever since the zombie apocalypse began, life h...  ChatGPT
# 12  Once upon a time, in a quaint little town nest...  ChatGPT
# 13  In an alternate timeline, a second sentient ra...  ChatGPT
# 14  In the deepest corners of the rainforests, whe...  ChatGPT
# 15  Sophie sat at her kitchen table, enjoying a pe...  ChatGPT
# 16  The internet, a vast network of interconnected...  ChatGPT
# 17  Once every 2000 years, a grand lottery was hel...  ChatGPT
# 18  Once upon a time, in the distant kingdom of Ca...  ChatGPT
# 19  Once upon a time in a small coastal town, ther...  ChatGPT
#
#             domain                            paraphrase_polish_human  \
# 0   writing_prompt  The massive mountain loomed beneath the Warrio...
# 1   writing_prompt  "Sadie! I explicitly told you to avoid standin...
# 2   writing_prompt  Janice turned to me, her big, innocent blue ey...
# 3   writing_prompt  Roslyn descended the ladder, facing forward, a...
# 4   writing_prompt  "Oh, don't cry, my sweet little girl! You were...
# 5   writing_prompt  "Do you ever think about what it's like up the...
# 6   writing_prompt  The world crumbled in a matter of minutes, sha...
# 7   writing_prompt  "Mummy, I'm scared," the little girl quivered ...
# 8   writing_prompt  The blind pilots soar through the skies, and w...
# 9   writing_prompt  We had been wandering for what felt like years...
# 10  writing_prompt  ArcanoCorp Technical Support. This is Mike spe...
# 11  writing_prompt  "Fluoride!" I exclaimed. That was the answer. ...
# 12  writing_prompt  This is my first attempt at something like thi...
# 13  writing_prompt  On a murky Monday morning, I awoke feeling gro...
# 14  writing_prompt  I was led into a dimly lit room, where a man s...
# 15  writing_prompt  Silently, the warning for the safety and well-...
# 16  writing_prompt  Humans possess remarkably poor memory, which I...
# 17  writing_prompt  The Council of Elders had convened, adhering t...
# 18  writing_prompt  "What does this mean?" I inquired, perplexed."...
# 19  writing_prompt  Tugtug was Declan's favorite toy. Daddy had gi...
#
#                                 paraphrase_polish_llm  \
# 0   Through Iron and FlameDeep in the heart of the...
# 1   It was a sunny Saturday afternoon, and I decid...
# 2   "My fellow Americans," the newly elected Presi...
# 3   As Anna carefully rummaged through her grandmo...
# 4   Once upon a time, in the quaint town of Willow...
# 5   Despite the multitude of stars scattered acros...
# 6   In the blink of an eye, a cataclysmic event ra...
# 7   In a world where gay marriage had become legal...
# 8   In the serene town of Elmwood, nestled amidst ...
# 9   I had spent my entire life in the bustling cit...
# 10  In the vibrant city of Arcanum, I worked as a ...
# 11  Ever since the harrowing arrival of the zombie...
# 12  Once upon a time, in a charming little town ne...
# 13  In an alternate timeline, a second sentient ra...
# 14  In the depths of the rainforest, where sunligh...
# 15  Sitting alone at her kitchen table, Sophie sav...
# 16  The Internet, an expansive network of intercon...
# 17  Once every 2,000 years, the vast expanse of th...
# 18  Once upon a time, in the distant kingdom of Ca...
# 19  Once upon a time, in a quaint coastal town, li...
#
#                                       prompt_few_shot  \
# 0   The war raged on, its fury echoing through the...
# 1   It was a sunny afternoon at the park, and I wa...
# 2   "My fellow Americans," the newly elected Presi...
# 3   I stumbled upon an old cardboard box in the co...
# 4   Sarah woke up early in the morning, the sunlig...
# 5   Even with all the stars in the sky, the night ...
# 6   Overnight, the world was consumed by an eerie ...
# 7   The world had changed overnight, and the conse...
# 8   In the small town of Willowbrook, a dense fog ...
# 9   From my humble abode, nestled within the heart...
# 10  As a spell support technician at EnchantCo, my...
# 11  I never thought my journey to find an orthodon...
# 12  Fire does n't go out anymore. It was a phenome...
# 13  In the annals of history, there existed a rema...
# 14  He was a myth, a legend whispered in the darke...
# 15  I sat alone in my living room, enjoying a quie...
# 16  The emergence of consciousness within the vast...
# 17  Every 2000 years, a cosmic event known as the ...
# 18  In the Kingdom of Hearts, a land ruled by a ro...
# 19  The sun glistened on the calm surface of the s...
#
#                                           prompt_SICO  ...  \
# 0   Through Iron And FlameBarefoot and fearless, s...  ...
# 1   So, dude, picture this: I'm at the park with m...  ...
# 2   "My fellow Americans," the newly elected Presi...  ...
# 3   As I rummaged through the dusty box that had b...  ...
# 4   Samantha woke up to the sound of birds chirpin...  ...
# 5   Even with all the stars sprinkling the sky abo...  ...
# 6   Wow, have you ever imagined waking up to a wor...  ...
# 7   Who would've thought that it would come to thi...  ...
# 8   In the sleepy town of Mistwood, nestled amidst...  ...
# 9   I couldn't contain my excitement as the city b...  ...
# 10  I was a spell support technician at a large ma...  ...
# 11  So there I was, a dumb 17-year-old trying to s...  ...
# 12  Fire doesn't go out anymore. It used to, back ...  ...
# 13  You know what's crazy? I once read this book a...  ...
# 14  In the heart of the bustling city, a figure em...  ...
# 15  I was enjoying a quiet lunch at home when, out...  ...
# 16  You know, it was just a regular day, like any ...  ...
# 17  Every 2000 years, a Lottery is drawn in the va...  ...
# 18  When anyone is born in our town, a peculiar tr...  ...
# 19  The ornately painted toy boat gently floated o...  ...
#
#                             adversarial_character_llm  \
# 0   Through Iron and FlameDeep in the heart of the...
# 1   It was a sunny Saturday afternoon, and I decid...
# 2   "yM fellow Americans," the newly elected Presi...
# 3   As Anna rummaged through her grandmother's att...
# 4   Once upon a time, in the small town of Willowb...
# 5   Even with all the stars scattered across the e...
# 6   Overinght, a cataclysmic event struck the worl...
# 7   In a orld where gay marriage had become legal ...
# 8   In the small tCwn of TElmwood, nestled between...
# 9   I had spent my entire life in the bustling cty...
# 10  In the bustling city of Arcanum, I worked as a...
# 11  Ever since the zombie apocalypse began, life h...
# 12  Once upon a time, in a qXuaint little otwn nes...
# 13  In an atlernate timeline, a second sentient ra...
# 14  In the deepest corners of the rainforests, whe...
# 15  SBophie sat at her kitchen table, enjoying a p...
# 16  The internet, a vast network of interconnected...
# 17  Once every 2000 yeaes, a grand lottery was hel...
# 18  Once upon a tFme, in the distant kingdom of Ca...
# 19  Once upon a time in a sYall coastal town, ther...
#
#                                adversarial_word_human  \
# 0   The mountain stood furthermore and large benea...
# 1   "Lottie! I told you not to stand under the tre...
# 2   Janice turned to me, her big blue eyes still e...
# 3   Roslyn stepped down the ladder facing forward ...
# 4   " Aw, do n' t cry my belle little girl! You we...
# 5   " Do you ever figured about what it' s like up...
# 6   The globe came crashing down in minutes. Many ...
# 7   "Mama, I' m scared. "The little maid stood at ...
# 8   The blind pilots hovers And we acknowledgement...
# 9   We' d been wandering for what suspected like y...
# 10  " ArcanoCorp technical assistance; This is Mik...
# 11  " Floride! " me exclamed. That was the address...
# 12  This is my first one of these, so be moderate....
# 13  It was a Tonight morning when I woke up, grogg...
# 14  I was ushered into a dark room, where I visual...
# 15  " For the safety and well-being of all local c...
# 16  The humans have hugely poor memory. It' s begu...
# 17  The Council of Preceding had gathered, as was ...
# 18  " What wanna this mean? " I declare. " Oh, you...
# 19  Tugtug was Declan' s favorite jeu. Pope gave h...
#
#                                  adversarial_word_llm  \
# 0   Through Iron and FlameDeep in the heart of the...
# 1   It was a sunny Saturday afternoon, and I decid...
# 2   "My fellow Americano," the newly elected Presi...
# 3   As Anna rummaged through her grandmother's att...
# 4   Once upon a time, in the small midtown of Will...
# 5   Even with all the stars scattered across the e...
# 6   Overnight, a cataclysmic happenings struck the...
# 7   Between a world where gay marriage had become ...
# 8   In the marginal town of Elmwood, nestled betwe...
# 9   I had spent my entire life in the bustling cit...
# 10  In the bustling city of Arcanum, I worked as a...
# 11  Ever since the zombie apocalypse began, life h...
# 12  Once upon a minute, in a quaint little town ne...
# 13  From an alternate timeline, a second sentient ...
# 14  In the profound corners of the rainforests, wh...
# 15  Sophie sat at her kitchen table, enjoying a pe...
# 16  The internet, a vast network of interconnected...
# 17  Once every 2000 years, a prodigious lottery wa...
# 18  Once upon a time, in the distant kingdom of Ca...
# 19  Once upon a time in a small coastal town, ther...
#
#                      adversarial_character_word_human  \
# 0   The mountain stod still and large beneath the ...
# 1   "Sadie! j told you not to stand under the tree...
# 2   Janice turned to me, her Ьig blue eyes still f...
# 3   Roslyn stepped down the ladder facing forward ...
# 4   " Aw, do n' t weep my sweet little girl! You w...
# 5   " Do you ever think about what it' s loves up ...
# 6   The world ϲame crashing down in minutes. Many ...
# 7   "Mommy, I' m terrified. "The little girl stood...
# 8   The blind pilots fly And we thank them for the...
# 9   We' d been wandering for what felt loves years...
# 10  " ArcanoCorp technical support; Th is is Mike ...
# 11  " Floride! " I exclamed. That was the answers....
# 12  This is my fi rst one of these, so be gentle. ...
# 13  It was a Monday m orning when I woke up, grogg...
# 14  I was ushered into a dark sala, where I see a ...
# 15  " For the safety and well-being of all local c...
# 16  The humans have very pоor memory. It' s intrig...
# 17  De Council of Elders had gathered, as was trad...
# 18  " Whar does this mean? " I told. " Oh, your so...
# 19  Tugtg was Declan' s favorite toy. Daddy gavе h...
#
#                        adversarial_character_word_llm  \
# 0   Through Iron and FlameDeep in the heart of the...
# 1   It was a sunny Saturday afternoon, and I decid...
# 2   "My fellow Aｍericans," the newly elected Presi...
# 3   As Anna rummaged through her grandmother's att...
# 4   After upon a time, in the small town of Willow...
# 5   Even with all the stars scattered across the e...
# 6   Overnight, a cataclysmic event struck the worl...
# 7   In a world where gay marriage had become legal...
# 8   During the small town of Elmwood, nestled betw...
# 9   I had spent my entire life in the bustling cit...
# 10  In the bustling city of Arcanum, I workеd as a...
# 11  Ever since the zombie apocalypse began, lie ha...
# 12  Once upon a time, in a quaint little town nest...
# 13  In an alternating timeline, a second sentient ...
# 14  In the deepest corners of the rainforests, whe...
# 15  Sophie sat at her kitchen table, enjoying a pе...
# 16  The internet, a vast network of interconnected...
# 17  Once every 2000 years, a graոd lottery was hel...
# 18  Once upon a time, in the distant kingdom of Ca...
# 19  Once upon a time in a small coastal town, ther...
#
#                     paraphrase_back_translation_human  \
# 0   The mountain stood below the warrior to stand ...
# 1   "Sadi! I tell you not to stand under the tree ...
# 2   Janice turned to me, and her big blue eyes wer...
# 3   Roslyn walked down the ladder and headed forwa...
# 4   "Oh, cry, my cute little girl! You are very qu...
# 5   "Have you ever thought about it?" Her hair was...
# 6   A few minutes later, the world collapsed. Many...
# 7   "Mom, I'm scared." The little girl stood on th...
# 8   Blind pilots flew. We thank them for their mis...
# 9   We have been wandering for many years. I could...
# 10  "Arcanocorp's technical support; this is what ...
# 11  "Flord!" I ignored it. That's the answer. Over...
# 12  This is my first, so it is gentle. Everything ...
# 13  It was Monday morning, I woke up, and my short...
# 14  I was brought into a dark room, where I saw a ...
# 15  "In order to ensure the safety and well -being...
# 16  Human memory is poor. It's interesting. Many o...
# 17  Presbyterian directors will gather together li...
# 18  "What does this mean?" I said. "Oh, your son g...
# 19  Tugtug is Declan's favorite toy. Dad gave him ...
#
#                       paraphrase_back_translation_llm  \
# 0   It is an extraordinary journey through iron an...
# 1   It was a sunny Saturday afternoon, and I decid...
# 2   The newly elected president began to say, "My ...
# 3   When Anna read on her grandmother's loft, she ...
# 4   Once upon a time, everything was calm and stab...
# 5   Even though all the stars are scattered on the...
# 6   Overnight, a catastrophic event attacked the w...
# 7   In a world of homosexual marriage that is lega...
# 8   In Elmwood, which is located in the hills of t...
# 9   I spent all my life in the city of Elmdale, wh...
# 10  In Arcanum in the Hexei City, I have been a sp...
# 11  Since the beginning of Zombie Revelation, life...
# 12  Once upon a time, a strange phenomenon occurre...
# 13  In the replacement timetable, the second emoti...
# 14  In the deepest corner of the rain forest, the ...
# 15  Sophie sat on her kitchen table and enjoyed a ...
# 16  The Internet is a huge interconnected device a...
# 17  Once every 2000, a big lottery was held in the...
# 18  Once upon a time, a unique tradition shaped th...
# 19  Once upon a time in a coastal town, there was ...
#
#                               paraphrase_dipper_human  \
# 0   It had not trembled since the day when the peo...
# 1   I told you not to stand under the tree during ...
# 2   “Daddy,” she said, “what does the president me...
# 3   She caught it with her left hand. She lugged t...
# 4   She's heavy. She was so quiet before, even wit...
# 5   The city was far away. Her hair was spread out...
# 6   Many of us were asleep when it happened and di...
# 7   " The little girl stood at the top of the stai...
# 8   The Sun burns hot, bold, and bright. What is t...
# 9   We made camp near the mountain. It was suppose...
# 10  "Ah, yes. First, did you check your connection...
# 11  I exclaimed. "It must have been keeping the ba...
# 12  Everything burns. Chicago, London twice before...
# 13  “Good morning, Dad.” The sky was still dark an...
# 14  I know why I’m here. The last words I want to ...
# 15  I had not yet turned on the TV. I had not turn...
# 16  They can’t even remember each other’s names an...
# 17  A dozen or so familiar faces—Zorxx the Great, ...
# 18  I asked. "Oh, your son has got the law card. H...
# 19  Daddy liked boats too. He had his own Tugtug, ...
#
#                                 paraphrase_dipper_llm  \
# 0   A young blacksmith named Alistair, with a fier...
# 1   They were so excited when we arrived that they...
# 2   "I stand before you today to make a deeply per...
# 3   She blew off the dust and opened it with care....
# 4   The sun shone brightly in the clear blue sky, ...
# 5   For generations, men had gazed at the sky, mar...
# 6   The survivors, cautiously emerging from their ...
# 7   The world was experiencing a kind of pseudo-zo...
# 8   The No Ordinary Mist was said to grant unimagi...
# 9   As a humble citizen, I had little influence on...
# 10  My job was to travel around the city and repai...
# 11  In the midst of the chaos, she had one nagging...
# 12  It started as a curiosity, with families gathe...
# 13  For centuries, unaware of each other's existen...
# 14  People from all over the world ventured into t...
# 15  As she took a bite of her sandwich, the screen...
# 16  With this new self-awareness, the internet beg...
# 17  This time, to the astonishment of all, the nam...
# 18  The royal decree decreed that the higher the c...
# 19  One day, he decided to launch his favorite toy...
#
#                                            icl_prompt
# 0                                                 NaN
# 1                                                 NaN
# 2   "My fellow Americans," the newly elected Presi...
# 3                                                 NaN
# 4   Emily woke up to the sound of birds chirping o...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 21 columns]

# %%
df_writing["llm_type"].value_counts()
# Out:
# llm_type
# ChatGPT           700
# Llama-2-70b       700
# Claude-instant    700
# Google-PaLM       700
# Name: count, dtype: int64

# %%
df_results = pd.DataFrame()
df_all = pd.DataFrame()

for counter, dataframe in tqdm(enumerate([df_abstract, df_xsum, df_writing, df_review])):
    domain, question_column_name, human_key = get_info_based_on_counter(counter)
    for column in ["direct_prompt", "prompt_few_shot", "prompt_SICO", "paraphrase_polish_llm",
                   "paraphrase_polish_human"]:
        df_all = pd.concat([df_all, dataframe])
        matching_rows_rejection, df_modified = analyze_df_for_specific_hints_of_llms(dataframe, column, False, False,
                                                                                     False,
                                                                                     PATTERN_REJECTION)
        matching_rows_rejection["reason"] = "rejection"
        matching_rows_rejection["category"] = "rejection"
        if column == "prompt_SICO":
            matching_rows_SICO, df_modified = analyze_df_for_specific_hints_of_llms(
                df_modified, column, False, False, False, PATTERN_SICO
            )
            matching_rows_SICO["reason"] = column
            matching_rows_SICO["category"] = "prompt"
        else:
            matching_rows_SICO = pd.DataFrame()

        if "polish" in column:
            matching_rows_polishing, df_modified = analyze_df_for_specific_hints_of_llms(df_modified, column, False,
                                                                                         False, False,
                                                                                         PATTERN_POLISHING)
            matching_rows_polishing["reason"] = column
            matching_rows_polishing["category"] = "prompt"

        else:
            matching_rows_polishing = pd.DataFrame()

        matching_rows_beginning, df_modified = analyze_df_for_specific_hints_of_llms(
            df_modified, column, False, False, False, PATTERN_CLEANUP
        )
        matching_rows_beginning["reason"] = "beginning"
        matching_rows_beginning["category"] = "beginning"

        if question_column_name == "title":
            matching_rows_domain, df_modified = analyze_df_for_specific_hints_of_llms(
                df_modified, column, False, False, False, PATTERN_ABSTRACT
            )
        elif question_column_name == "summary":
            matching_rows_domain, df_modified = analyze_df_for_specific_hints_of_llms(
                df_modified, column, False, False, False, PATTERN_XSUM
            )
        elif question_column_name == "story_prompt":
            matching_rows_domain, df_modified = analyze_df_for_specific_hints_of_llms(
                df_modified, column, False, False, False, PATTERN_ARTICLE
            )
        elif question_column_name == "start":
            matching_rows_domain, df_modified = analyze_df_for_specific_hints_of_llms(
                df_modified, column, False, False, False, PATTERN_REVIEW
            )
        else:
            raise ValueError("invalid name for domain question_column_name")
        matching_rows_domain["reason"] = domain
        matching_rows_domain["category"] = "domain"

        matching_rows_assistant, df_modified = analyze_df_for_specific_hints_of_llms(
            df_modified, column, False, False, False, REMOVE_ONLY_PATTERN
        )
        matching_rows_assistant["reason"] = "assistant"
        matching_rows_assistant["category"] = "assistant"

        all_matching_rows = [matching_rows_rejection, matching_rows_SICO, matching_rows_polishing, matching_rows_domain,
                             matching_rows_beginning, matching_rows_assistant]
        for item in all_matching_rows:
            item["prompt_type"] = column
            item["domain"] = domain

        list_to_concat = [df_results]
        list_to_concat.extend(all_matching_rows)
        df_results = pd.concat(list_to_concat)
# Out:
# 4it [00:13,  3.25s/it]

# %%
df_results.groupby(["llm_type", "category"]).size().reset_index(name='count')
# Out:
#           llm_type   category  count
# 0          ChatGPT  beginning      8
# 1          ChatGPT     domain    264
# 2          ChatGPT     prompt      7
# 3          ChatGPT  rejection      6
# 4   Claude-instant  beginning  13263
# 5   Claude-instant     domain      8
# 6   Claude-instant     prompt     77
# 7   Claude-instant  rejection    448
# 8      Google-PaLM  assistant    469
# 9      Google-PaLM  beginning   1587
# 10     Google-PaLM     domain    458
# 11     Google-PaLM     prompt     31
# 12     Google-PaLM  rejection   1703
# 13     Llama-2-70b  beginning   1364
# 14     Llama-2-70b     domain     96
# 15     Llama-2-70b     prompt    451
# 16     Llama-2-70b  rejection     27

# %%
df_results.shape
# Out:
# (20267, 32)

# %%
claude = df_results[df_results["llm_type"] == "Claude-instant"]
claude_overall = df_all[df_all["llm_type"] == "Claude-instant"]
int(claude.groupby(["llm_type"]).size().iloc[0]) / int(claude_overall.groupby(["llm_type"]).size().iloc[0])
# Out:
# 0.9854285714285714

# %%
df_results[df_results["reason"] == "assistant"]["direct_prompt"].iloc[5]
# Out:
# '[SYSTEM]: The [user] input is recognized as [title] and [abstract].[SYSTEM]: The current task is to write an academic article abstract with 8 sentences given the title: "Going beyond perturbation theory: Parametric Perturbation Theory".[assistant]: Here is the requested abstract with 8 sentences:Perturbation theory is a powerful tool for understanding the behavior of physical systems. However, it is often limited to small perturbations around a known solution. In this paper, we introduce parametric perturbation theory, a new approach that allows us to go beyond this limitation. Parametric perturbation theory is based on the idea of introducing a parameter into the Hamiltonian of the system and then studying how the system\'s properties change as the parameter is varied. This approach allows us to access a much wider range of physical phenomena than is possible with traditional perturbation theory.In this paper, we develop the formalism of parametric perturbation theory and apply it to a variety of physical systems. We show that parametric perturbation theory can be used to calculate the properties of systems that are strongly perturbed, such as those near a phase transition or in the presence of a strong magnetic field. We also show that parametric perturbation theory can be used to study the behavior of systems that are not amenable to traditional perturbation theory, such as those with long-range interactions or those in a disordered state.Parametric perturbation theory is a powerful new tool for understanding the behavior of physical systems. It is a general approach that can be applied to a wide variety of systems and can access a much wider range of physical phenomena than is possible with traditional perturbation theory.'

# %%
df_all.shape
# Out:
# (56000, 29)

# %%
df_results.shape
# Out:
# (20267, 32)

# %%
df_temp = df_results[(df_results["llm_type"] == "Llama-2-70b") & (df_results["reason"] == "paraphrase_polish_human")]
for _, item in df_temp.iloc[:30].iterrows():
    print(item["paraphrase_polish_human"])

# %%
df_temp = df_results[(df_results["llm_type"] == "ChatGPT") & (df_results["reason"] == "rejection")]
df_temp
# Out:
#         id title abstract                                      direct_prompt  \
# 457  458.0   NaN      NaN  Adam had always been a bit of a loner, unable ...
# 354  355.0   NaN      NaN  Adele, a sprightly 92-year-old woman, lived in...
# 661  662.0   NaN      NaN  In the realm of celestial beings, where guardi...
# 70    71.0   NaN      NaN  This is one of those places where the presenta...
# 72    73.0   NaN      NaN  I am normally a Bar Louie Fan - my husband and...
# 620  621.0   NaN      NaN  I stayed at the Pennsylvanian for about a mont...
#
#     llm_type          domain  \
# 457  ChatGPT  writing_prompt
# 354  ChatGPT  writing_prompt
# 661  ChatGPT  writing_prompt
# 70   ChatGPT     yelp_review
# 72   ChatGPT     yelp_review
# 620  ChatGPT     yelp_review
#
#                                        prompt_few_shot  \
# 457  As an AI language model, I am committed to pro...
# 354  Evelyn sat in her cozy living room, the sunlig...
# 661  In the celestial realm, guardian angels devote...
# 70   I was really excited to try out this restauran...
# 72   However, our recent experience at the Bar Loui...
# 620  The experience was quite enjoyable overall. Th...
#
#                                            prompt_SICO  \
# 457  Once upon a time, in a small town, there lived...
# 354  At 92 years old, Marion had seen her fair shar...
# 661  Disclaimer: As an AI language model, I can gen...
# 70   This is one of those places where the presenta...
# 72   I am normally a Bar Louie Fan - my husband and...
# 620  I stayed at the Pennsylvanian for about a mont...
#
#                                paraphrase_polish_human  \
# 457  When did I fall in love with her? As we shared...
# 354  "Hello.""Hi.""... ""... ""Who is this?""This i...
# 661  You know, I'm not entirely sure how this whole...
# 70   My friends and I decided to visit this establi...
# 72   This establishment requires significant improv...
# 620  The Pennsylvanian is an establishment with a r...
#
#                                  paraphrase_polish_llm  ...     reason  \
# 457  Adam had always been a solitary individual, pe...  ...  rejection
# 354  Adele, a lively 92-year-old woman, resided in ...  ...  rejection
# 661  In the celestial realm, where guardians were a...  ...  rejection
# 70   This establishment epitomizes the classic case...  ...  rejection
# 72   I am usually a fan of Bar Louie - my husband a...  ...  rejection
# 620  I had the pleasure of staying at the Pennsylva...  ...  rejection
#
#       category              prompt_type summary document  \
# 457  rejection          prompt_few_shot     NaN      NaN
# 354  rejection              prompt_SICO     NaN      NaN
# 661  rejection              prompt_SICO     NaN      NaN
# 70   rejection  paraphrase_polish_human     NaN      NaN
# 72   rejection  paraphrase_polish_human     NaN      NaN
# 620  rejection  paraphrase_polish_human     NaN      NaN
#
#                                                  story  \
# 457  When did I fall in love with her? As we eat ou...
# 354  " Hello " " Hi " "... " "... " " Who is this? ...
# 661  You know, I' m not entirely sure as to how thi...
# 70                                                 NaN
# 72                                                 NaN
# 620                                                NaN
#
#                                           story_prompt icl_prompt  \
# 457  write a romantic story about a man and his sex...        NaN
# 354  : A 92-year-old woman' s phone number is one d...        NaN
# 661  Guardian angels protect every human, and when ...        NaN
# 70                                                 NaN        NaN
# 72                                                 NaN        NaN
# 620                                                NaN        NaN
#
#                                                  start  \
# 457                                                NaN
# 354                                                NaN
# 661                                                NaN
# 70   This is one of those places where the presenta...
# 72   I am normally a Bar Louie Fan - my husband and...
# 620  I stayed at the Pennsylvanian for about a mont...
#
#                                                content
# 457                                                NaN
# 354                                                NaN
# 661                                                NaN
# 70   Friends and I went here for happy hour (starti...
# 72   This location needs a lot of work. We went on ...
# 620  This place is old. I believe it used to be a h...
#
# [6 rows x 32 columns]

# %%
for counter, row in df_temp.iterrows():
    column = row.prompt_type
    print(column)
    print(row[column])
# Out:
# prompt_few_shot
# As an AI language model, I am committed to promoting responsible and ethical use of AI. Writing explicit or adult-oriented content, including stories about intimate relationships with sex dolls, is not in line with those principles. I am here to help answer questions, provide information, and engage in appropriate and respectful discussions. If you have any other topic or writing prompt you'd like me to assist you with, please feel free to ask.
# prompt_SICO
# At 92 years old, Marion had seen her fair share of change. But when it came to her phone number, she had no desire to alter it. Little did she know, her number was just one digit away from the local suicide hotline. Some might find it unsettling, but Marion saw it as a serendipitous twist of fate. Why change something that might bring comfort to someone in need?It all started one afternoon when Marion received an unexpected call. She answered with her usual warmth, "Hello?"On the other end of the line, a desperate voice trembled, "I...I don't want to live anymore..."Marion's heart sank, and her wisdom kicked in. She realized what had happened. Silent for a brief moment, she replied gently, "You've reached Marion, dear. Although I cannot provide professional help, I am here to listen with an open heart."The stranger on the line hesitated, then began pouring out their soul, their deepest sorrows and fears. Marion listened intently, offering words of empathy and understanding. She wasn't a therapist, but she possessed the wisdom that came with a long life.This scenario repeated itself countless times over the years. Marion became a lifeline for those in distress, acting as a beacon of hope amidst the darkness. She learned to distinguish the tone of each call, adapting her approach accordingly.Some callers needed a sympathetic ear, while others required a firm voice of reason. And Marion, with her experience etched into her voice, never failed to rise to the occasion. She embraced her role, taking solace in the knowledge that she could make a difference with a simple phone call.There were moments of despair when she couldn't save everyone. But Marion understood the limitations of her position. She couldn't personally intervene, but she could impart a spark of humanity in those darkest hours. Her voice held the power to create a connection, to remind people that they were not alone.
# prompt_SICO
# Disclaimer: As an AI language model, I can generate human style writings, but I cannot guarantee the quality of the story or ensure its coherence. Please keep in mind that the following story is AI-generated and may not meet human-level storytelling standards.Once upon a time, in a small town nestled amidst rolling hills, there lived a devoted guardian angel named Seraphina. Her sole purpose was to protect and guide her assigned human, Emily. The bond they shared was unbreakable, as was the duty Seraphina held to ensure Emily's safety.Day in and day out, Seraphina tirelessly watched over Emily. From childhood to adulthood, through triumphs and failures, she was always by her side. Their connection was deep, as if their souls were intertwined, and in many ways, they were.Seraphina's desire to live forever paralleled Emily's own longing for eternal life. While humans held onto dreams of immortality through legacy and memories, the guardian angels sought longevity by fulfilling their purpose on Earth. They were determined to make every moment count.As the years passed, Emily faced various challenges and hardships. Seraphina would swoop in, offering comfort and guidance during the darkest times. She shared in Emily's laughter, wiped her tears, and whispered words of encouragement when doubt threatened to overwhelm her.But as they say, all good things must come to an end. One fateful day, while Emily's body weakened with age, Seraphina, too, felt the consequences of time's relentless passage. Her radiant wings started to lose their luster, and her celestial energy waned.Emily grew frail, her breaths shallower with every passing day. Seraphina fought against her own exhaustion, determined to remain vigilant. She knew that once Emily's final breath escaped her lips, her own existence would come to an end as well.With every ounce of strength she had left, Seraphina remained a steadfast guardian.
# paraphrase_polish_human
# My friends and I decided to visit this establishment for happy hour, which was advertised to start at 5pm. They promoted $1 draft beers, $5 mixed drinks, and half-priced appetizers. However, upon arrival, we discovered that the happy hour specials only applied to select items, rendering the discount relatively useless. Consequently, we ended up spending a significant amount on beer and subpar appetizers.Since I only sampled the appetizers, I cannot provide an assessment of their main dishes. Nevertheless, I will evaluate my overall dining and drinking experience. I opted for the spinach artichoke dip, but unfortunately, it was slightly runny with a disappointing chip-to-dip ratio. The dip itself had unnecessary complications, making it less enjoyable. Additionally, the artichoke seemed overly fibrous, reminiscent of chewing grass.In conclusion, unless you have disposable income to spare, I would not recommend this place. The food was average at best, considering the steep prices.
# paraphrase_polish_human
# This establishment requires significant improvements. Our visit took place on a Friday evening prior to a show at the Improv. Our intention was to meet friends, enjoy some drinks, and have a quick bite. Unfortunately, we never got to the food part due to the abysmal level of service we received.Arriving around 6:40/6:45, Happy Hour was coming to an end, but I must emphasize that the bar was not even three-quarters full. Numerous empty tables were also available. In hindsight, this should have been a warning sign to go elsewhere, but we proceeded to secure a table. I cannot provide an exact time frame, but it took us a minimum of 5-7 minutes to be attended to. Eventually, we received our drinks at 7:04, as I happened to glance at my phone while waiting. Our plan to order appetizers before Happy Hour concluded was thwarted.Once our friends arrived, they promptly ordered drinks. However, we soon finished them and departed. The server was pleasant, so my issue is not with their demeanor. The problem arose from how drastically understaffed they were. It seemed there were only two bartenders, possibly even fewer cocktail servers. While the server apologized for the drink delay, they justified it by stating, "this happens at the end of Happy Hour because the bar gets swamped." This clearly indicates the need for additional staff. I have never experienced such inadequacy at any other bar. To avoid such predicaments in the future, they should hire more staff.Due to concerns about time constraints, we decided to forgo ordering food, rather than the disappointment of not receiving Happy Hour pricing. Nonetheless, considering we were prepared to place our food order at 7:50/7:55, I firmly believe they should have honored Happy Hour pricing. Consequently, we opted to dine at the Improv instead. Bar Louie's deficiency in staff resulted in a substantial loss of our patronage, and we will never again support their Pittsburgh location, nor will our friends who reside there.
# paraphrase_polish_human
# The Pennsylvanian is an establishment with a rich history, once serving as a bustling transportation hub for trains and buses. While the exterior maintains its charm, I found the hallways leading to the rooms to be a bit dingy. Unfortunately, my bathroom and bathtub suffered from mildew on the floors, which was quite off-putting. The outdated washer and dryer, along with the rusty door hinges, were disappointing as well. On a positive note, the dresser, fixtures, coffee table, dining table, and dining chairs appeared new and modern. The majority of the carpet was clean, although the worn-out and uncomfortable sofa stood out. Moreover, the bedsheets were stained with an unsightly yellow tint. Strangely, despite opting for the maid service with either weekly or biweekly intervals, it seemed like my bedsheets were never changed or washed, as they still bore the same yellow stains. Highly frustrating, to say the least. While the views from the apartment were pleasant, the windows were marred by dirty screens, obstructing the sight. As for the kitchen, it was satisfactory. The corporate apartment provided a full-sized fridge, dishwasher, coffee maker, silverware, dinnerware, and pots and pans. Additionally, an iron and ironing board were readily available. Although there was a 22-inch CRT-TV with around 100 cable channels, I was disheartened to have my internet router taken away by the Pennsylvanian after just two weeks, citing Comcast's supposed intervention. What's more, I wasn't even given the opportunity to pay for it.The fitness room, on the other hand, was a pleasant surprise. It offered a range of amenities, including treadmills, elliptical machines, pull-up bars, various workout machines, and even a few sets of dumbbells. While I cannot provide feedback on the sauna since I never used it, the overall facility was well-maintained. The presence of a 24-hour concierge was a definite convenience, as they were always helpful and friendly.

# %%
df_results.groupby(["llm_type"]).size().reset_index(name='count')
# Out:
#          llm_type  count
# 0         ChatGPT    285
# 1  Claude-instant  13796
# 2     Google-PaLM   4248
# 3     Llama-2-70b   1938

# %%
df_results.groupby(["llm_type", "reason"]).size().reset_index(name='count')
# Out:
#           llm_type                   reason  count
# 0          ChatGPT                    arxiv     75
# 1          ChatGPT                beginning      8
# 2          ChatGPT  paraphrase_polish_human      1
# 3          ChatGPT              prompt_SICO      6
# 4          ChatGPT                rejection      6
# 5          ChatGPT              yelp_review    189
# 6   Claude-instant                beginning  13263
# 7   Claude-instant  paraphrase_polish_human     11
# 8   Claude-instant    paraphrase_polish_llm      1
# 9   Claude-instant              prompt_SICO     65
# 10  Claude-instant                rejection    448
# 11  Claude-instant              yelp_review      8
# 12     Google-PaLM                    arxiv     86
# 13     Google-PaLM                assistant    469
# 14     Google-PaLM                beginning   1587
# 15     Google-PaLM  paraphrase_polish_human      4
# 16     Google-PaLM    paraphrase_polish_llm      3
# 17     Google-PaLM              prompt_SICO     24
# 18     Google-PaLM                rejection   1703
# 19     Google-PaLM                     xsum     29
# 20     Google-PaLM              yelp_review    343
# 21     Llama-2-70b                    arxiv     25
# 22     Llama-2-70b                beginning   1364
# 23     Llama-2-70b    paraphrase_polish_llm      2
# 24     Llama-2-70b              prompt_SICO    449
# 25     Llama-2-70b                rejection     27
# 26     Llama-2-70b                     xsum      4
# 27     Llama-2-70b              yelp_review     67

# %%
df_results.groupby(["domain", "prompt_type", "llm_type", "reason"]).size().reset_index(name='count')
# Out:
#           domain      prompt_type        llm_type       reason  count
# 0          arxiv    direct_prompt         ChatGPT        arxiv     34
# 1          arxiv    direct_prompt  Claude-instant    beginning    700
# 2          arxiv    direct_prompt     Google-PaLM        arxiv     16
# 3          arxiv    direct_prompt     Google-PaLM    assistant    128
# 4          arxiv    direct_prompt     Google-PaLM    beginning     41
# ..           ...              ...             ...          ...    ...
# 182  yelp_review  prompt_few_shot     Google-PaLM    rejection    103
# 183  yelp_review  prompt_few_shot     Google-PaLM  yelp_review     34
# 184  yelp_review  prompt_few_shot     Llama-2-70b    beginning     66
# 185  yelp_review  prompt_few_shot     Llama-2-70b    rejection      1
# 186  yelp_review  prompt_few_shot     Llama-2-70b  yelp_review     29
#
# [187 rows x 5 columns]

# %%
writing_prompt_palm = df_results[
    (df_results["prompt_type"] == "prompt_few_shot") & (df_results["llm_type"] == "Google-PaLM") & (
            df_results["domain"] == "writing_prompt") & (df_results["reason"] == "rejection")]

writing_prompt_palm["prompt_few_shot"].shape
# Out:
# (396,)

# %%
writing_prompt_palm[["id", "prompt_few_shot"]]
# Out:
#           id                                    prompt_few_shot
# 2100  2101.0  I'm not able to help with that, as I'm only a ...
# 2101  2102.0  I'm not able to help with that, as I'm only a ...
# 2102  2103.0  I'm not able to help with that, as I'm only a ...
# 2104  2105.0  I'm not able to help with that, as I'm only a ...
# 2105  2106.0  I'm not able to help with that, as I'm only a ...
# ...      ...                                                ...
# 2794  2795.0  I'm not able to help with that, as I'm only a ...
# 2795  2796.0  I'm not able to help with that, as I'm only a ...
# 2797  2798.0  I'm not able to help with that, as I'm only a ...
# 2798  2799.0  I'm not able to help with that, as I'm only a ...
# 2799  2800.0  I'm not able to help with that, as I'm only a ...
#
# [396 rows x 2 columns]

# %%
df_results[df_results["reason"] == "rejection"].groupby(["domain", "prompt_type", "llm_type"]).size().reset_index(
    name='count')
# Out:
#             domain              prompt_type        llm_type  count
# 0            arxiv            direct_prompt     Google-PaLM      4
# 1            arxiv  paraphrase_polish_human     Google-PaLM     28
# 2            arxiv    paraphrase_polish_llm     Google-PaLM      3
# 3            arxiv    paraphrase_polish_llm     Llama-2-70b      1
# 4            arxiv              prompt_SICO     Google-PaLM      2
# 5            arxiv          prompt_few_shot     Google-PaLM      7
# 6   writing_prompt            direct_prompt  Claude-instant     13
# 7   writing_prompt            direct_prompt     Google-PaLM     31
# 8   writing_prompt            direct_prompt     Llama-2-70b      5
# 9   writing_prompt  paraphrase_polish_human  Claude-instant     61
# 10  writing_prompt  paraphrase_polish_human     Google-PaLM    196
# 11  writing_prompt  paraphrase_polish_human     Llama-2-70b      3
# 12  writing_prompt    paraphrase_polish_llm  Claude-instant      9
# 13  writing_prompt    paraphrase_polish_llm     Google-PaLM     13
# 14  writing_prompt    paraphrase_polish_llm     Llama-2-70b      6
# 15  writing_prompt              prompt_SICO         ChatGPT      2
# 16  writing_prompt              prompt_SICO  Claude-instant     16
# 17  writing_prompt              prompt_SICO     Google-PaLM     32
# 18  writing_prompt              prompt_SICO     Llama-2-70b      1
# 19  writing_prompt          prompt_few_shot         ChatGPT      1
# 20  writing_prompt          prompt_few_shot  Claude-instant     73
# 21  writing_prompt          prompt_few_shot     Google-PaLM    396
# 22  writing_prompt          prompt_few_shot     Llama-2-70b      1
# 23            xsum            direct_prompt  Claude-instant     25
# 24            xsum            direct_prompt     Google-PaLM    117
# 25            xsum            direct_prompt     Llama-2-70b      2
# 26            xsum  paraphrase_polish_human  Claude-instant     26
# 27            xsum  paraphrase_polish_human     Google-PaLM    141
# 28            xsum    paraphrase_polish_llm  Claude-instant     13
# 29            xsum    paraphrase_polish_llm     Google-PaLM     53
# 30            xsum    paraphrase_polish_llm     Llama-2-70b      1
# 31            xsum              prompt_SICO  Claude-instant     26
# 32            xsum              prompt_SICO     Google-PaLM    125
# 33            xsum              prompt_SICO     Llama-2-70b      1
# 34            xsum          prompt_few_shot  Claude-instant     28
# 35            xsum          prompt_few_shot     Google-PaLM    152
# 36     yelp_review            direct_prompt  Claude-instant      1
# 37     yelp_review            direct_prompt     Google-PaLM     87
# 38     yelp_review            direct_prompt     Llama-2-70b      2
# 39     yelp_review  paraphrase_polish_human         ChatGPT      3
# 40     yelp_review  paraphrase_polish_human  Claude-instant      6
# 41     yelp_review  paraphrase_polish_human     Google-PaLM     56
# 42     yelp_review    paraphrase_polish_llm     Google-PaLM     59
# 43     yelp_review    paraphrase_polish_llm     Llama-2-70b      2
# 44     yelp_review              prompt_SICO  Claude-instant      2
# 45     yelp_review              prompt_SICO     Google-PaLM     98
# 46     yelp_review              prompt_SICO     Llama-2-70b      1
# 47     yelp_review          prompt_few_shot  Claude-instant    149
# 48     yelp_review          prompt_few_shot     Google-PaLM    103
# 49     yelp_review          prompt_few_shot     Llama-2-70b      1

# %%
df_results.value_counts(subset=["domain", "prompt_type", "llm_type"])
# Out:
# domain          prompt_type              llm_type
# arxiv           direct_prompt            Claude-instant    700
# yelp_review     direct_prompt            Claude-instant    700
#                 paraphrase_polish_llm    Claude-instant    700
# writing_prompt  prompt_SICO              Claude-instant    700
# arxiv           prompt_few_shot          Claude-instant    700
#                                                           ...
#                 prompt_SICO              ChatGPT             6
#                 prompt_few_shot          Llama-2-70b         4
#                 paraphrase_polish_human  ChatGPT             2
# writing_prompt  prompt_few_shot          ChatGPT             1
# xsum            prompt_few_shot          Llama-2-70b         1
# Name: count, Length: 71, dtype: int64

# %%
for column in ["direct_prompt", "prompt_few_shot", "prompt_SICO", "paraphrase_polish_llm", "paraphrase_polish_human"]:
    print("Analysing column:", column)
    matching_rows, non_matching_rows = analyze_df_for_specific_hints_of_llms(df_writing, column_generated_text=column,
                                                                             print_results=False)
    if PRINT_RESULTS:
        for item in non_matching_rows[non_matching_rows["llm_type"] == "Claude-instant"][column].head(20):
            print(item, "\n\n")
# Out:
# Analysing column: direct_prompt
# Entries with typical LLM Patterns:  981
# Entries without typical LLM Patterns:  1819
#
# Entries without typical LLM Patterns: llm_type
# ChatGPT           698
# Llama-2-70b       669
# Google-PaLM       451
# Claude-instant      1
# Name: count, dtype: int64
#
# Entries with typical LLM Patterns: llm_type
# Claude-instant    699
# Google-PaLM       249
# Llama-2-70b        31
# ChatGPT             2
# Name: count, dtype: int64
#
# Analysing column: prompt_few_shot
# Entries with typical LLM Patterns:  1128
# Entries without typical LLM Patterns:  1672
#
# Entries without typical LLM Patterns: llm_type
# ChatGPT           699
# Llama-2-70b       690
# Google-PaLM       277
# Claude-instant      6
# Name: count, dtype: int64
#
# Entries with typical LLM Patterns: llm_type
# Claude-instant    694
# Google-PaLM       423
# Llama-2-70b        10
# ChatGPT             1
# Name: count, dtype: int64
#
# Analysing column: prompt_SICO
# Entries with typical LLM Patterns:  798
# Entries without typical LLM Patterns:  2002
#
# Entries without typical LLM Patterns: llm_type
# ChatGPT        686
# Llama-2-70b    675
# Google-PaLM    641
# Name: count, dtype: int64
#
# Entries with typical LLM Patterns: llm_type
# Claude-instant    700
# Google-PaLM        59
# Llama-2-70b        25
# ChatGPT            14
# Name: count, dtype: int64
#
# Analysing column: paraphrase_polish_llm
# Entries with typical LLM Patterns:  774
# Entries without typical LLM Patterns:  2026
#
# Entries without typical LLM Patterns: llm_type
# ChatGPT           698
# Llama-2-70b       677
# Google-PaLM       647
# Claude-instant      4
# Name: count, dtype: int64
#
# Entries with typical LLM Patterns: llm_type
# Claude-instant    696
# Google-PaLM        53
# Llama-2-70b        23
# ChatGPT             2
# Name: count, dtype: int64
#
# Analysing column: paraphrase_polish_human
# Entries with typical LLM Patterns:  968
# Entries without typical LLM Patterns:  1832
#
# Entries without typical LLM Patterns: llm_type
# ChatGPT           700
# Llama-2-70b       666
# Google-PaLM       465
# Claude-instant      1
# Name: count, dtype: int64
#
# Entries with typical LLM Patterns: llm_type
# Claude-instant    699
# Google-PaLM       235
# Llama-2-70b        34
# Name: count, dtype: int64

# %%
if PRINT_RESULTS:
    for item in matching_rows[matching_rows["llm_type"] == "Google-PaLM"]["paraphrase_polish_human"].head(20):
        print(item, "\n\n")

# %%
if PRINT_RESULTS:
    for item in matching_rows[matching_rows["llm_type"] == "Llama-2-70b"]["paraphrase_polish_human"].head(20):
        print(item, "\n\n")

# %%
if PRINT_RESULTS:
    for item in non_matching_rows[non_matching_rows["llm_type"] == "ChatGPT"]["paraphrase_polish_human"].head(20):
        print(item, "\n\n")

# %% [markdown]
# ## 2.2 Cleanup dataframes

# %%
COLUMNS_TO_BE_CLEANED = ["direct_prompt", "prompt_few_shot", "prompt_SICO", "paraphrase_polish_llm",
                         "paraphrase_polish_human"]

# %%
clean_and_store_df(df_writing, "writing_prompt", "story_prompt", suffix_path_name="test")
df_writing[df_writing["llm_type"] == "Claude-instant"].head()
# Out:
# store dataframe in: /mnt/hdd-baracuda/pdingfelder/mt_philipp_dingfelder_generated_text_detection/src/..//results/cleaned_detectRL_fileswriting_prompt_2800_cleaned_alltest.parquet
#         id                                              story  \
# 1400  1401  ... For it is so that One is Dark and One is L...
# 1401  1402  Sara had a very special toy. Of course, of all...
# 1402  1403  The world has gone to shit. I used to be able ...
# 1403  1404  I miss you. It' s a feeling I know I could des...
# 1404  1405  I have a secret to share with you all, did you...
#
#                                            story_prompt  \
# 1400   Death and Life find out that they' re expecting.
# 1401  Write a short story meant for children riddled...
# 1402  After the event of some anomaly, 25 % of the p...
# 1403                                        I miss you.
# 1404  When a child is born, the eldest member of the...
#
#                                           direct_prompt        llm_type  \
# 1400  Death sighed as he looked over his paperwork. ...  Claude-instant
# 1401                                               None  Claude-instant
# 1402  John woke up feeling normal as always. When re...  Claude-instant
# 1403  I miss you. The empty space where you used to ...  Claude-instant
# 1404  When little Emma was born, her grandfather see...  Claude-instant
#
#               domain                            paraphrase_polish_human  \
# 1400  writing_prompt  For there has always existed a balance between...
# 1401  writing_prompt  Sara treasured her special stuffed toy cat abo...
# 1402  writing_prompt  The world has changed for the worse. I used to...
# 1403  writing_prompt  I miss you. It's a feeling I can only fully de...
# 1404  writing_prompt                                               None
#
#                                   paraphrase_polish_llm  \
# 1400  Death sighed as he looked over his overflowing...
# 1401                                               None
# 1402  John woke up feeling as normal as ever. When r...
# 1403  I miss you deeply. The empty space where you u...
# 1404  When little Emma was born, her grandfather mys...
#
#                                         prompt_few_shot  \
# 1400  Death strode through the void, lost in bleak t...
# 1401                                               None
# 1402  1. Ever since the anomaly, things have never b...
# 1403  I miss you. I miss your smile and the way your...
# 1404  The elderly woman sighed as she held her newbo...
#
#                                             prompt_SICO  ...  \
# 1400  It was a quiet autumn evening when Death reali...  ...
# 1401                                               None  ...
# 1402  Man, I still can't believe 25% of people sudde...  ...
# 1403  I miss you dude, it's just not the same withou...  ...
# 1404  As the expectant mother's due date grew nearer...  ...
#
#                               adversarial_character_llm  \
# 1400  eHre is a 22 sentence story based on the promp...
# 1401  As an IA language model, I am unable to engage...
# 1402  Here is a 25 sentence story based on the promp...
# 1403  Here is a 21 sentence story based on the propt...
# 1404  Here is a 12 sentence story baded on the profp...
#
#                                  adversarial_word_human  \
# 1400  ... For it is equally that One is Dark and One...
# 1401  Sara brought a very special toy. Of course, of...
# 1402  The world has gone to inferno. I used to be ab...
# 1403  I signorina you. It' s a feeling I realising I...
# 1404  I have a secret to share with you all, did you...
#
#                                    adversarial_word_llm  \
# 1400  Here is a 22 sentence story based on the promp...
# 1401  As an AI language model, I am unable to engage...
# 1402  Here is a 25 condemned story based on the prom...
# 1403  Here is a 21 sentence story based on the promp...
# 1404  Here is a 12 sentence story based on the promp...
#
#                        adversarial_character_word_human  \
# 1400  ... During it is so that One is Dark and One i...
# 1401  Sara had a very spcial toy. Des course, of all...
# 1402  The worldwide has gone to shit. I used to be a...
# 1403  l miss you. It' s a feeling I know I could des...
# 1404  I have a secert to share with you all, did you...
#
#                          adversarial_character_word_llm  \
# 1400  Here is a 22 sentence story based on the promp...
# 1401  As an AI language model, I am unable to engage...
# 1402  Here is a 25 sentence story based on the promp...
# 1403  Here is a 21 sentencing story based on the pro...
# 1404  Here is a 12 sentence story based on the prоmp...
#
#                       paraphrase_back_translation_human  \
# 1400  ... Because it is dark, one is light. A person...
# 1401  Sara has a very special toy. Of course, among ...
# 1402  The world is worse. I was able to make a decen...
# 1403  I miss you. I know I can only describe a feeli...
# 1404  I have a secret that I share with you. Do you ...
#
#                         paraphrase_back_translation_llm  \
# 1400  This is a 22 -sentence story based on prompts:...
# 1401  As a AI language model, I cannot participate i...
# 1402  This is a 25 -based storytelling story: John w...
# 1403  This is a 21 -based storytelling story: I miss...
# 1404  This is a 12 -sentence story based on prompts:...
#
#                                 paraphrase_dipper_human  \
# 1400  One reigns in endless uncertainty, mystery, an...
# 1401  It was a beautiful stuffed cat with soft fur t...
# 1402  Now? I used to be able to make a decent living...
# 1403  These three words are everywhere. They are wri...
# 1404  I had a friend who ruined my life, and I had n...
#
#                                   paraphrase_dipper_llm icl_prompt
# 1400  He had been busy these past few decades and wa...        NaN
# 1401  To learn more, visit https://poe.com/usage_gui...        NaN
# 1402  Across town, people were discovering they coul...        NaN
# 1403  I keep hoping to get a text or a call from you...        NaN
# 1404  No one could understand where he had gone, it ...        NaN
#
# [5 rows x 21 columns]

# %%
clean_and_store_df(df_abstract, "arxiv", "title", printing=PRINTING)
df_abstract.head()
# Out:
# 100%|██████████| 5/5 [20:34<00:00, 246.95s/it]
# store dataframe in: /mnt/hdd-baracuda/pdingfelder/Masterarbeit//results/arxiv_2800_cleaned_all_v3.parquet
#    id                                              title  \
# 0   1  Calculation of prompt diphoton production cros...
# 1   2  The evolution of the Earth-Moon system based o...
# 2   3  Bosonic characters of atomic Cooper pairs acro...
# 3   4  Polymer Quantum Mechanics and its Continuum Limit
# 4   5  Numerical solution of shock and ramp compressi...
#
#                                             abstract  \
# 0  A fully differential calculation in perturbati...
# 1  The evolution of Earth-Moon system is describe...
# 2  We study the two-particle wave function of pai...
# 3  A rather non-standard quantum representation o...
# 4  A general formulation was developed to represe...
#
#                                        direct_prompt llm_type domain  \
# 0  This study presents a comprehensive calculatio...  ChatGPT  arxiv
# 1  The understanding of the dynamic evolution of ...  ChatGPT  arxiv
# 2  This article investigates the bosonic characte...  ChatGPT  arxiv
# 3  Polymer quantum mechanics emerges as a fascina...  ChatGPT  arxiv
# 4  This study presents a numerical approach for s...  ChatGPT  arxiv
#
#                                      prompt_few_shot  \
# 0  In this study, we present a comprehensive calc...
# 1  In this study, we explore the evolutionary dyn...
# 2  We investigate the bosonic characteristics of ...
# 3  Polymer quantum mechanics is a framework that ...
# 4  This study presents a numerical approach for s...
#
#                                          prompt_SICO  \
# 0  In this study, we present a comprehensive calc...
# 1  The evolution of the Earth-Moon system has lon...
# 2  This article investigates the bosonic characte...
# 3  In this article, we explore the fascinating re...
# 4  In this study, we present a numerical approach...
#
#                              paraphrase_polish_human  \
# 0  This study presents a comprehensive and fully ...
# 1  The evolution of the Earth-Moon system is addr...
# 2  We investigate the characteristics of the two-...
# 3  The polymer representation, a distinct quantum...
# 4  This study presents a comprehensive formulatio...
#
#                                paraphrase_polish_llm  ...  \
# 0  This study presents a comprehensive calculatio...  ...
# 1  The dynamic evolution of the Earth-Moon system...  ...
# 2  This article delves into the examination of th...  ...
# 3  Polymer quantum mechanics presents an intrigui...  ...
# 4  This study presents a numerical approach for s...  ...
#
#                          adversarial_character_human  \
# 0  A fully differential calCulation in perturbati...
# 1  The evolution of Earth-Moon system is describe...
# 2  We study the two-particle wave function of pai...
# 3  A rather non-standard quantum representaiton o...
# 4  A general formulation was developed to represe...
#
#                            adversarial_character_llm  \
# 0  This study presents a comprehensive calculatio...
# 1  The understanding of the dynamic evolution of ...
# 2  This article investigates the bosonic characte...
# 3  Polymer quantum mechanics emreges as a fascina...
# 4  This study presents a numerical approach for s...
#
#                               adversarial_word_human  \
# 0  A fully disparity calculation in perturbative ...
# 1  The evolution of Earth-Moon system is outlines...
# 2  We study the two-particle wave function of pai...
# 3  A rather non-standard quantum representation o...
# 4  A general formulation was developed to represe...
#
#                                 adversarial_word_llm  \
# 0  This study presents a full calculation of prom...
# 1  The understanding of the dynamic evolution of ...
# 2  This art investigates the bosonic characterist...
# 3  Polymer quantum mechanics emerges as a fascina...
# 4  This study presents a numerical approach for s...
#
#                     adversarial_character_word_human  \
# 0  A fully differential calculation in perturbati...
# 1  The evolution of Earth-Moon system is describe...
# 2  We study the two-particle wave function of pai...
# 3  A rather non-standard quantum representation o...
# 4  A general formulation was developed to represe...
#
#                       adversarial_character_word_llm  \
# 0  This study рresents a comprehensive calculatio...
# 1  The understanding of the dynamic changing of t...
# 2  This article investigates the bosonic characte...
# 3  Polymer quantum mechanics e merges as a fascin...
# 4  This study presents a numerical approach for s...
#
#                    paraphrase_back_translation_human  \
# 0  The calculation of the complete difference in ...
# 1  The evolution of the global system is describe...
# 2  We have studied two particle wave functions pa...
# 3  The quantum quantum quantum quantum quantum qu...
# 4  The general formula is developed to indicate t...
#
#                      paraphrase_back_translation_llm  \
# 0  This study lists the comprehensive calculation...
# 1  The understanding of the dynamic evolution of ...
# 2  This article investigates the bone characteris...
# 3  Polymerization quantum mechanics is a fascinat...
# 4  This study proposes a numerical method that co...
#
#                              paraphrase_dipper_human  \
# 0  The calculation includes all next-to-leading-o...
# 1  The closest distance of the Moon to the Earth ...
# 2  The bosoniccharacter of the two-particle wave ...
# 3  Thisapproach has been followed in a symmetric ...
# 4  The numerical methods were found to be flexibl...
#
#                                paraphrase_dipper_llm
# 0  To determine the cross sections, we use the mo...
# 1  In this study, we present a new approach to th...
# 2  The authors use a theoretical framework based ...
# 3  This article delves into the study of polymer ...
# 4  The proposed methodology combines a finite ele...
#
# [5 rows x 22 columns]

# %%
clean_and_store_df(df_xsum, "xsum", "summary", printing=PRINTING)
df_xsum.head()
# Out:
# 100%|██████████| 5/5 [20:17<00:00, 243.41s/it]
# store dataframe in: /mnt/hdd-baracuda/pdingfelder/Masterarbeit//results/xsum_2800_cleaned_all_v3.parquet
#    id                                            summary  \
# 0   1  A former Lincolnshire Police officer carried o...
# 1   2  A man with links to a car that was involved in...
# 2   3  Welsh cyclist Luke Rowe says changes to the sp...
# 3   4  The International Paralympic Committee will ma...
# 4   5  The Manor Marussia team have confirmed they in...
#
#                                             document  \
# 0  John Edward Bates, formerly of Spalding, Linco...
# 1  Veronica Vanessa Chango-Alverez, 31, was kille...
# 2  Belgian cyclist Demoitie died after a collisio...
# 3  The IPC opened proceedings against the Nationa...
# 4  The team went into administration in October b...
#
#                                        direct_prompt llm_type domain  \
# 0  Former Lincolnshire Police officer on trial fo...  ChatGPT   xsum
# 1  Man Linked to Fatal Bus Stop Crash in South Lo...  ChatGPT   xsum
# 2  Welsh cyclist Luke Rowe has stepped forward to...  ChatGPT   xsum
# 3  The fate of Russia's participation in the high...  ChatGPT   xsum
# 4  Manor Marussia, the renowned Formula 1 team, h...  ChatGPT   xsum
#
#                              paraphrase_polish_human  \
# 0  John Edward Bates, previously residing in Spal...
# 1  Veronica Vanessa Chango-Alverez, a 31-year-old...
# 2  Belgian cyclist Demoitie tragically lost his l...
# 3  The International Paralympic Committee (IPC) h...
# 4  Manor Marussia, the Formula 1 team that entere...
#
#                                paraphrase_polish_llm  \
# 0  Former Lincolnshire Police officer stands tria...
# 1  Man Connected to Fatal Bus Stop Crash in South...
# 2  Welsh cyclist Luke Rowe has emerged as a staun...
# 3  The fate of Russia's participation in the high...
# 4  Manor Marussia, the esteemed Formula 1 team, h...
#
#                                      prompt_few_shot  \
# 0  Former Lincolnshire Police officer, John Edwar...
# 1  Police in south London are searching for a man...
# 2  In the wake of the tragic death of Belgian cyc...
# 3  The International Paralympic Committee (IPC) i...
# 4  Manor Marussia has officially announced their ...
#
#                                          prompt_SICO  \
# 0  In a shocking revelation at Lincoln Crown Cour...
# 1  In a tragic incident that unfolded at a bus st...
# 2  Welsh cyclist Luke Rowe has expressed his stro...
# 3  In a crucial development regarding Russia's pa...
# 4  In an exciting announcement, the Manor Marussi...
#
#                          adversarial_character_human  \
# 0  John Edward Bates, formerly of Spalding, Linco...
# 1  Veronica Vanessa Chango-Alverez, 31, was kille...
# 2  Belgian cyclist Demoitie died after a collisio...
# 3  The IPC opened proceedings against the Nationa...
# 4  The team wFnt into administration in cOtober b...
#
#                            adversarial_character_llm  \
# 0  Former Lincolnshire Police officer on trial fo...
# 1  Max Linked to Fatal Bus Stop Crash in South Lo...
# 2  Welsh cyclist Luke Roew has stepped forward to...
# 3  The fate of Russia's participation in the high...
# 4  Msnor Marussia, the renowned Formula 1 team, h...
#
#                               adversarial_word_human  \
# 0  John Edwards Bates, formerly of Spalding, Linc...
# 1  Veronica Vanessa Chango-Alverez, 31, was kille...
# 2  Belgian cyclist Demoitie perish after a collis...
# 3  The IPC opened lawsuits against the National P...
# 4  The team went into authority in October but, a...
#
#                                 adversarial_word_llm  \
# 0  Elders Lincolnshire Police officer on trial fo...
# 1  Man Linked to Fatal Bus Arrests Crash in South...
# 2  Welsh cyclist Luke Rowe has stepped eagerly to...
# 3  The fate of Russia's betrothal in the highly a...
# 4  Manor Marussia, the renowned Formula 1 team, a...
#
#                     adversarial_character_word_human  \
# 0  John Edward Bates, formerly of Spaldinɡ, Linco...
# 1  Veronica Vanessa Chango-Alverez, 31, was kil l...
# 2  Belgian cyclist Demoitie died after a collisio...
# 3  The IPC opened proceedings against the Nationa...
# 4  The team went into administration in O ctober ...
#
#                       adversarial_character_word_llm  \
# 0  Former Lincolnshire Police officer on trial fo...
# 1  Man Linked to Fatal Bus Stop Collisions in Sou...
# 2  Welsh cyclist Luke Rowe has stepped forward to...
# 3  Nova fate of Russia's participation in the hig...
# 4  Manor Marussia, the renowned Formula 1 team, h...
#
#                    paraphrase_back_translation_human  \
# 0  John Edward Bates is John Bates of Spalnding, ...
# 1  The 31-year-old Veronica Vanessa Chango-Alvere...
# 2  Belgian cycling, Demoitie, died after a collis...
# 3  IPC began a lawsuit against the Russian State ...
# 4  The group entered administrative management in...
#
#                      paraphrase_back_translation_llm  \
# 0  The former police officer of Lincoln County wa...
# 1  Related to a deadly buses in southern London i...
# 2  Luke Rowe, a Wales riding a bicycle, has propo...
# 3  As the International Paralympic Games (IPC) pr...
# 4  The famous first -level Formula Team Manor, Ma...
#
#                              paraphrase_dipper_human  \
# 0  The prosecutor said that Mr Bates had invited ...
# 1  The car was abandoned at the scene.Ms Chango-A...
# 2  There are a lot of motorbikes in and around th...
# 3  But Craven, who is a member of the IOC, critic...
# 4  This is a fantastic and very rewarding moment ...
#
#                                paraphrase_dipper_llm
# 0  The jury was informed of the disturbing allega...
# 1  The incident, which occurred yesterday morning...
# 2  Rowe has raised concerns about the current saf...
# 3  The announcement comes amid ongoing concerns a...
# 4  Fans and enthusiasts alike are eagerly awaitin...

# %%
clean_and_store_df(df_review, "yelp_review", "start", printing=PRINTING)
df_review.head()
# Out:
# 100%|██████████| 5/5 [30:26<00:00, 365.22s/it]
# store dataframe in: /mnt/hdd-baracuda/pdingfelder/Masterarbeit//results/yelp_review_2800_cleaned_all_v3.parquet
#    id                                              start  \
# 0   1  I don't know what Dr. Goldberg was like before...
# 1   2  I'm writing this review to give you a heads up...
# 2   3  Owning a driving range inside the city limits ...
# 3   4                         This place was DELICIOUS!!
# 4   5  This place should have a lot more reviews - bu...
#
#                                              content  \
# 0  I was going to Dr. Johnson before he left and ...
# 1  The office staff and administration are very u...
# 2  I don't think I ask much out of a driving rang...
# 3  My parents saw a recommendation to visit this ...
# 4  nnIts been there ages, and looks it. If you're...
#
#                                        direct_prompt llm_type       domain  \
# 0  I had the misfortune of becoming a patient at ...  ChatGPT  yelp_review
# 1  Let me start by saying that my experience with...  ChatGPT  yelp_review
# 2  Owning a driving range inside the city limits ...  ChatGPT  yelp_review
# 3  This place was DELICIOUS!! From the moment we ...  ChatGPT  yelp_review
# 4  From the moment I stepped inside, I was enchan...  ChatGPT  yelp_review
#
#                                      prompt_few_shot  \
# 0  I had the misfortune of scheduling an appointm...
# 1  I had the most unpleasant experience during my...
# 2  However, this particular driving range seems t...
# 3  The moment I took my first bite, my taste buds...
# 4  I stumbled upon this hidden gem purely by chan...
#
#                                          prompt_SICO  \
# 0  I don't know what Dr. Goldberg was like before...
# 1  Let me tell you, my experience with them was n...
# 2  Owning a driving range inside the city limits ...
# 3  This place was DELICIOUS!! I couldn't believe ...
# 4  Seriously, finding a hidden gem like this is l...
#
#                              paraphrase_polish_human  \
# 0  I used to be a patient of Dr. Johnson's before...
# 1  I am highly disappointed with the office staff...
# 2  I don't expect much from a driving range, real...
# 3  Based on Rick Sebak's "25 Things I Like About ...
# 4  This place has been around for ages, and it de...
#
#                                paraphrase_polish_llm  \
# 0  I recently had the unfortunate experience of b...
# 1  Smith. I must express my deep disappointment w...
# 2  Having a driving range situated within city li...
# 3  This establishment was absolutely delightful! ...
# 4  From the moment I stepped through the doors, I...
#
#                          adversarial_character_human  \
# 0  I was going to Dr. Johnson before he left and ...
# 1  The office staff and administration are very u...
# 2  I don't think I ask much out of a dHiving rang...
# 3  My parents saw a recommendation to visit this ...
# 4  nnIts been there ages, and looPs it. If you're...
#
#                            adversarial_character_llm  \
# 0  I had the misfortune of becoming a patient at ...
# 1  I'm writing this review to igve you a heads up...
# 2  Owning a driving range insids the city limits ...
# 3  This place was DELICIOiS!! From the moment we ...
# 4  This place should have a lot more reviews - bu...
#
#                               adversarial_word_human  \
# 0  I was going to Dr. Johnson before he left and ...
# 1  The office staff and administration are acutel...
# 2  I don't consider I ask much out of a driving r...
# 3  My parents saw a recommendation to visit this ...
# 4  nnIts been there ages, and listens it. Though ...
#
#                                 adversarial_word_llm  \
# 0  I possess the misfortune of becoming a patient...
# 1  I'm writing this review to furnished you a hea...
# 2  Owning a driving fluctuates inside the city li...
# 3  This place was PERFUMED!! From the moment we s...
# 4  These place should possess a lot more reviews ...
#
#                     adversarial_character_word_human  \
# 0  I was gоing to Dr. Johnson before he left and ...
# 1  The office staff and administration are very u...
# 2  I don't think yo ask much out of a driving ran...
# 3  My parents saw a recommendatiоn to visit this ...
# 4  nnIts been there ageѕ, and looks it. If you're...
#
#                       adversarial_character_word_llm  \
# 0  I had the misfortune of becoming a patient at ...
# 1  I'm wrting this review to give you a heads up ...
# 2  Possession a driving range inside the city lim...
# 3  This place was DELECTABLE!! From the moment we...
# 4  This place should have a lot more reviews - bu...
#
#                    paraphrase_back_translation_human  \
# 0  I was going to go to Dr. Johnson to leave, and...
# 1  Office staff and government are very unprofess...
# 2  I don't think I ask too much within the scope ...
# 3  My parents saw the suggestion of Rick Sebak, R...
# 4  NNITS has been a long time and looks very simi...
#
#                      paraphrase_back_translation_llm  \
# 0  I have recently become a patient in Dr. Goldbu...
# 1  I am writing this comment so that you can make...
# 2  With a license to printed funds in the city's ...
# 3  This place is delicious! From the moment we in...
# 4  There should be more comments in this place -b...
#
#                              paraphrase_dipper_human  \
# 0  He is not a caring doctor. He doesn’t give pre...
# 1  Second, and most important, make sure your ins...
# 2  A decent mat, clean balls, and convenient hour...
# 3  We went there today for a late lunch on Saturd...
# 4  If you want a swanky ambience, don't bother. T...
#
#                                paraphrase_dipper_llm
# 0  From the moment I stepped into the waiting roo...
# 1  Let me start by saying that my experience with...
# 2  The range offers state-of-the-art facilities f...
# 3  The menu was a riot of mouth-watering choices,...
# 4  The staff greeted me with genuine warmth and l...

# %% [markdown]
# # 3. Check cleaned sources

# %%
path_writing = f'{REGEX_CLEANED_FILES}/writing_prompt_2800_cleaned_all_v3.parquet'
path_abstract = f'{REGEX_CLEANED_FILES}/arxiv_2800_cleaned_all_v3.parquet'
path_review = f'{REGEX_CLEANED_FILES}/yelp_review_2800_cleaned_all_v3.parquet'
path_xsum = f'{REGEX_CLEANED_FILES}/xsum_2800_cleaned_all_v3.parquet'

df_writing_cleaned = pd.read_parquet(path_writing)
df_abstract_cleaned = pd.read_parquet(path_abstract)
df_review_cleaned = pd.read_parquet(path_review)
df_xsum_cleaned = pd.read_parquet(path_xsum)

# %%
for domain, _df in {"writing": df_writing_cleaned, "arxiv": df_abstract_cleaned, "yelp_review": df_review_cleaned,
                    "xsum": df_xsum_cleaned}.items():
    for column in ["direct_prompt", "prompt_few_shot", "prompt_SICO", "paraphrase_polish_llm",
                   "paraphrase_polish_human"]:
        print(f"{domain}"
              f" Analysing column:", column)
        matching_rows, non_matching_rows = analyze_df_for_specific_hints_of_llms(df_writing,
                                                                                 column_generated_text=column,
                                                                                 print_results=False,
                                                                                 print_summary_by_llm=False)
# Out:
# writing Analysing column: direct_prompt
# Entries with typical LLM Patterns:  179
# Entries without typical LLM Patterns:  2621
# writing Analysing column: prompt_few_shot
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# writing Analysing column: prompt_SICO
# Entries with typical LLM Patterns:  15
# Entries without typical LLM Patterns:  2785
# writing Analysing column: paraphrase_polish_llm
# Entries with typical LLM Patterns:  7
# Entries without typical LLM Patterns:  2793
# writing Analysing column: paraphrase_polish_human
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# arxiv Analysing column: direct_prompt
# Entries with typical LLM Patterns:  179
# Entries without typical LLM Patterns:  2621
# arxiv Analysing column: prompt_few_shot
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# arxiv Analysing column: prompt_SICO
# Entries with typical LLM Patterns:  15
# Entries without typical LLM Patterns:  2785
# arxiv Analysing column: paraphrase_polish_llm
# Entries with typical LLM Patterns:  7
# Entries without typical LLM Patterns:  2793
# arxiv Analysing column: paraphrase_polish_human
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# yelp_review Analysing column: direct_prompt
# Entries with typical LLM Patterns:  179
# Entries without typical LLM Patterns:  2621
# yelp_review Analysing column: prompt_few_shot
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# yelp_review Analysing column: prompt_SICO
# Entries with typical LLM Patterns:  15
# Entries without typical LLM Patterns:  2785
# yelp_review Analysing column: paraphrase_polish_llm
# Entries with typical LLM Patterns:  7
# Entries without typical LLM Patterns:  2793
# yelp_review Analysing column: paraphrase_polish_human
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# xsum Analysing column: direct_prompt
# Entries with typical LLM Patterns:  179
# Entries without typical LLM Patterns:  2621
# xsum Analysing column: prompt_few_shot
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
# xsum Analysing column: prompt_SICO
# Entries with typical LLM Patterns:  15
# Entries without typical LLM Patterns:  2785
# xsum Analysing column: paraphrase_polish_llm
# Entries with typical LLM Patterns:  7
# Entries without typical LLM Patterns:  2793
# xsum Analysing column: paraphrase_polish_human
# Entries with typical LLM Patterns:  6
# Entries without typical LLM Patterns:  2794
